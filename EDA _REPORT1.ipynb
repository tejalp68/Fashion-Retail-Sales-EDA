# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Exploratory Data Analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods

# %%
# importing libraries

# %%
import pandas  as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# importing dataset

# %%
df=pd.read_csv("Fashion_Retail_Sales.csv")
df
# Out:
#       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 0                      4018        Handbag                 4619.0
# 1                      4115          Tunic                 2456.0
# 2                      4019       Tank Top                 2102.0
# 3                      4097       Leggings                 3126.0
# 4                      3997         Wallet                 3003.0
# ...                     ...            ...                    ...
# 3395                   4118         Shorts                   37.0
# 3396                   4056       Slippers                  176.0
# 3397                   3991         Onesie                    NaN
# 3398                   4042        Sandals                  128.0
# 3399                   4001       Backpack                  115.0
#
#      Date Purchase  Review Rating Payment Method
# 0       2023-02-05            NaN    Credit Card
# 1       2023-07-11            2.0    Credit Card
# 2       2023-03-23            4.1           Cash
# 3       2023-03-15            3.2           Cash
# 4       2022-11-27            4.7           Cash
# ...            ...            ...            ...
# 3395    2023-07-09            2.7           Cash
# 3396    2023-03-16            2.5           Cash
# 3397    2022-10-03            2.4    Credit Card
# 3398    2023-01-01            1.8           Cash
# 3399    2023-03-22            1.4           Cash
#
# [3400 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer Reference ID  3400 non-null   int64
#  1   Item Purchased         3400 non-null   object
#  2   Purchase Amount (USD)  2750 non-null   float64
#  3   Date Purchase          3400 non-null   object
#  4   Review Rating          3076 non-null   float64
#  5   Payment Method         3400 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 159.5+ KB

# %%
df.describe()
# Out:
#        Customer Reference ID  Purchase Amount (USD)  Review Rating
# count            3400.000000            2750.000000    3076.000000
# mean             4039.660588             156.709818       2.999057
# std                48.122583             419.536669       1.156505
# min              3957.000000              10.000000       1.000000
# 25%              3997.000000              57.000000       2.000000
# 50%              4040.000000             110.000000       3.000000
# 75%              4081.000000             155.750000       4.000000
# max              4122.000000            4932.000000       5.000000

# %%
# finding null values per column
df.isnull().sum()
# Out:
# Customer Reference ID      0
# Item Purchased             0
# Purchase Amount (USD)    650
# Date Purchase              0
# Review Rating            324
# Payment Method             0
# dtype: int64

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 0                      4018        Handbag                 4619.0
# 1                      4115          Tunic                 2456.0
# 2                      4019       Tank Top                 2102.0
# 3                      4097       Leggings                 3126.0
# 4                      3997         Wallet                 3003.0
# ...                     ...            ...                    ...
# 3395                   4118         Shorts                   37.0
# 3396                   4056       Slippers                  176.0
# 3397                   3991         Onesie                    NaN
# 3398                   4042        Sandals                  128.0
# 3399                   4001       Backpack                  115.0
#
#      Date Purchase  Review Rating Payment Method
# 0       2023-02-05            NaN    Credit Card
# 1       2023-07-11            2.0    Credit Card
# 2       2023-03-23            4.1           Cash
# 3       2023-03-15            3.2           Cash
# 4       2022-11-27            4.7           Cash
# ...            ...            ...            ...
# 3395    2023-07-09            2.7           Cash
# 3396    2023-03-16            2.5           Cash
# 3397    2022-10-03            2.4    Credit Card
# 3398    2023-01-01            1.8           Cash
# 3399    2023-03-22            1.4           Cash
#
# [3400 rows x 6 columns]>

# %%
df.columns
# Out:
# Index(['Customer Reference ID', 'Item Purchased', 'Purchase Amount (USD)',
#        'Date Purchase', 'Review Rating', 'Payment Method'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     Customer Reference ID Item Purchased  Purchase Amount (USD) Date Purchase  \
# 0                    4018        Handbag                 4619.0    2023-02-05
# 1                    4115          Tunic                 2456.0    2023-07-11
# 2                    4019       Tank Top                 2102.0    2023-03-23
# 3                    4097       Leggings                 3126.0    2023-03-15
# 4                    3997         Wallet                 3003.0    2022-11-27
# 5                    4080         Onesie                 2914.0    2022-12-11
# 6                    4055         Jacket                 2571.0    2023-07-08
# 7                    3973       Trousers                 2419.0    2022-11-10
# 8                    4044          Jeans                 4771.0    2023-05-19
# 9                    4010        Loafers                 4233.0    2023-06-11
# 10                   4108       Slippers                 2356.0    2023-03-19
# 11                   4067         Bowtie                 4418.0    2022-11-21
# 12                   4068        Pajamas                 3728.0    2022-12-09
# 13                   4102    Trench Coat                 2130.0    2023-01-29
# 14                   4044        Handbag                 2122.0    2023-08-01
# 15                   4096         Poncho                 2383.0    2023-04-10
# 16                   4017         Gloves                 2895.0    2023-07-17
# 17                   4001    Trench Coat                 2952.0    2023-06-13
# 18                   3976       Slippers                 4069.0    2023-06-18
# 19                   4103         Romper                 4465.0    2022-11-21
#
#     Review Rating Payment Method
# 0             NaN    Credit Card
# 1             2.0    Credit Card
# 2             4.1           Cash
# 3             3.2           Cash
# 4             4.7           Cash
# 5             4.5    Credit Card
# 6             1.3           Cash
# 7             4.6           Cash
# 8             4.1           Cash
# 9             NaN    Credit Card
# 10            4.8    Credit Card
# 11            3.4           Cash
# 12            NaN    Credit Card
# 13            4.8           Cash
# 14            1.2    Credit Card
# 15            NaN    Credit Card
# 16            3.6    Credit Card
# 17            2.2           Cash
# 18            4.9    Credit Card
# 19            NaN    Credit Card

# %%
df['Review Rating'] = df['Review Rating'].fillna(df['Review Rating'].mode()[0])
df['Purchase Amount (USD)'] = df['Purchase Amount (USD)'].fillna(df['Purchase Amount (USD)'].mean())

# %%
df
# Out:
#       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 0                      4018        Handbag            4619.000000
# 1                      4115          Tunic            2456.000000
# 2                      4019       Tank Top            2102.000000
# 3                      4097       Leggings            3126.000000
# 4                      3997         Wallet            3003.000000
# ...                     ...            ...                    ...
# 3395                   4118         Shorts              37.000000
# 3396                   4056       Slippers             176.000000
# 3397                   3991         Onesie             156.709818
# 3398                   4042        Sandals             128.000000
# 3399                   4001       Backpack             115.000000
#
#      Date Purchase  Review Rating Payment Method
# 0       2023-02-05            4.1    Credit Card
# 1       2023-07-11            2.0    Credit Card
# 2       2023-03-23            4.1           Cash
# 3       2023-03-15            3.2           Cash
# 4       2022-11-27            4.7           Cash
# ...            ...            ...            ...
# 3395    2023-07-09            2.7           Cash
# 3396    2023-03-16            2.5           Cash
# 3397    2022-10-03            2.4    Credit Card
# 3398    2023-01-01            1.8           Cash
# 3399    2023-03-22            1.4           Cash
#
# [3400 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Customer Reference ID    0
# Item Purchased           0
# Purchase Amount (USD)    0
# Date Purchase            0
# Review Rating            0
# Payment Method           0
# dtype: int64

# %%
plt.hist(df['Purchase Amount (USD)'].head(50) , color= 'orange',edgecolor='black')
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("ITEM PRICE")
plt.show()

# %%
df.head(20)
# Out:
#     Customer Reference ID Item Purchased  Purchase Amount (USD) Date Purchase  \
# 0                    4018        Handbag                 4619.0    2023-02-05
# 1                    4115          Tunic                 2456.0    2023-07-11
# 2                    4019       Tank Top                 2102.0    2023-03-23
# 3                    4097       Leggings                 3126.0    2023-03-15
# 4                    3997         Wallet                 3003.0    2022-11-27
# 5                    4080         Onesie                 2914.0    2022-12-11
# 6                    4055         Jacket                 2571.0    2023-07-08
# 7                    3973       Trousers                 2419.0    2022-11-10
# 8                    4044          Jeans                 4771.0    2023-05-19
# 9                    4010        Loafers                 4233.0    2023-06-11
# 10                   4108       Slippers                 2356.0    2023-03-19
# 11                   4067         Bowtie                 4418.0    2022-11-21
# 12                   4068        Pajamas                 3728.0    2022-12-09
# 13                   4102    Trench Coat                 2130.0    2023-01-29
# 14                   4044        Handbag                 2122.0    2023-08-01
# 15                   4096         Poncho                 2383.0    2023-04-10
# 16                   4017         Gloves                 2895.0    2023-07-17
# 17                   4001    Trench Coat                 2952.0    2023-06-13
# 18                   3976       Slippers                 4069.0    2023-06-18
# 19                   4103         Romper                 4465.0    2022-11-21
#
#     Review Rating Payment Method
# 0             4.1    Credit Card
# 1             2.0    Credit Card
# 2             4.1           Cash
# 3             3.2           Cash
# 4             4.7           Cash
# 5             4.5    Credit Card
# 6             1.3           Cash
# 7             4.6           Cash
# 8             4.1           Cash
# 9             4.1    Credit Card
# 10            4.8    Credit Card
# 11            3.4           Cash
# 12            4.1    Credit Card
# 13            4.8           Cash
# 14            1.2    Credit Card
# 15            4.1    Credit Card
# 16            3.6    Credit Card
# 17            2.2           Cash
# 18            4.9    Credit Card
# 19            4.1    Credit Card

# %%
plt.pie(df['Review Rating'].head(10) ,labels=df["Item Purchased"].head(10) ,autopct ='%1.f%%')
plt.title("Pie chart of Review Rating and Item Purchased")

plt.show()

# %%
df['Payment Method'].head(10).info
# Out:
# <bound method Series.info of 0    Credit Card
# 1    Credit Card
# 2           Cash
# 3           Cash
# 4           Cash
# 5    Credit Card
# 6           Cash
# 7           Cash
# 8           Cash
# 9    Credit Card
# Name: Payment Method, dtype: object>

# %%
count = df['Payment Method'].value_counts()
print(count)
# Out:
# Payment Method
# Credit Card    1770
# Cash           1630
# Name: count, dtype: int64
